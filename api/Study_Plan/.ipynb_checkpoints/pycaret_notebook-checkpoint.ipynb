# %%
import pandas as pd
from pycaret.classification import *

# %%
df = pd.read_csv('study_plan.csv')
df
# Out:
#     Gender  Age  What time do you wake up in the morning?  \
# 0   Female   28                                      5.00
# 1   Female   21                                      3.00
# 2     Male   22                                      4.00
# 3     Male   27                                      2.00
# 4     Male   23                                      1.00
# 5     Male   24                                      6.00
# 6     Male   26                                      8.00
# 7     Male   28                                      9.00
# 8     Male   30                                      4.00
# 9   Female   24                                      3.00
# 10    Male   22                                      6.00
# 11    Male   23                                      7.00
# 12    Male   29                                      7.00
# 13  Female   24                                      2.00
# 14    Male   22                                      5.00
# ...

# %%
cat_features = ['Category Number', 'Rating No']
experiment = setup(df, target='Meal Plan No', categorical_features=cat_features)
# Out:
# <style  type="text/css" >
# #T_fff93_row44_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_fff93_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fff93_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_fff93_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_fff93_row0_col1" class="data row0 col1" >1846</td>
#             </tr>
#             <tr>
#                         <th id="T_fff93_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_fff93_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_fff93_row1_col1" class="data row1 col1" >Meal Plan No</td>
#             </tr>
#             <tr>
# ...

# %%
best_model = compare_models()
# Out:
# <style  type="text/css" >
#     #T_c21fb_ th {
#           text-align: left;
# ...

# %%
top3 = compare_models(n_select = 3)
# Out:
# <style  type="text/css" >
#     #T_cc34d_ th {
#           text-align: left;
# ...

# %%
save_model(top3[0], model_name='meal_plan_naive_bayes')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=['Category Number',
#                                                              'Rating No'],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[],
#                                        ml_usecase='classification',
#                                        numerical_features=[],
#                                        target='Meal Plan No',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_val...
#                  ('binn', 'passthrough'), ('rem_outliers', 'passthrough'),
# ...
